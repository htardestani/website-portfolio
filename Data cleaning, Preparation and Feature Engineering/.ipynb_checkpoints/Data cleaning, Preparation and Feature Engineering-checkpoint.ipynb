# %% [markdown]
# ___
# [Home- go back to hadardestani.com](http://hadiardestani.com/)
# ___
# # Data Cleaning and Preparation
#
# A few years ago I borrowed some money from Lending club while I was in school and needed some money. I was very happy with the process and how fast everything worked out. And of course, I paid it off to the last penny. But this is not always the case. Some people default on their loans. How does lending club trust you to borrow money? Of course, they use their past Data, consumer Data, and statistics to determine what is the probability of a potential borrower to pay back in full, and based on their formula they approve or reject the request. I will try to download publically available data from their website and try to create a model that will help predict whether if a potential borrower will pay back in full or not.
#
# I will be using their data from 2019 Q4 (I could download the whole year or even a few years of data but it would be really hard on my machine running big datasets. This smaller dataset will serve the purpose here!) and try to classify and predict whether or not the borrower paid back their loan in full. I downloaded the data from [here](https://www.lendingclub.com/info/download-data.action) (of course I had a username and password since I once was a browser so I just had to reset my password.) At the end of this practice I will download the end result dataset so I can use it for modeling an algorithm in another post.

# %% [markdown]
# # Libraries
#
# ***Let's first import the usual libraries***

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
# %matplotlib inline

# %% [markdown]
# ## The Data
#
# ***I am going to use pandas to import my CSV file***

# %%
lending_club = pd.read_csv('/Users/hadiardestani/Desktop/LoanStats3d_securev1.csv',skiprows=1,low_memory=False)

# %%
#I am going to work off of a copy of the data frame, so my machine doesn't have to re-read the entire data frame every time.
#this will save me some memory.
df = lending_club.copy(deep=True)
df.head()
# Out:
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  68616873        NaN     8000.0       8000.0           8000.0   36 months
# 1  68466916        NaN    25000.0      25000.0          25000.0   36 months
# 2  68577849        NaN    18000.0      18000.0          18000.0   60 months
# 3  68526907        NaN    16000.0      16000.0          16000.0   60 months
# 4  68596180        NaN    20000.0      20000.0          20000.0   36 months
#
#   int_rate  installment grade sub_grade       ...        \
# 0   11.48%       263.74     B        B5       ...
# 1    7.49%       777.55     A        A4       ...
# 2   11.99%       400.31     C        C1       ...
# 3   17.97%       406.04     D        D4       ...
# 4    5.32%       602.30     A        A1       ...
#
#   orig_projected_additional_accrued_interest hardship_payoff_balance_amount  \
# 0                                        NaN                            NaN
# 1                                        NaN                            NaN
# 2                                        NaN                            NaN
# 3                                        NaN                            NaN
# 4                                        NaN                            NaN
#
#   hardship_last_payment_amount  debt_settlement_flag  \
# 0                          NaN                     N
# 1                          NaN                     N
# 2                          NaN                     N
# 3                          NaN                     N
# 4                          NaN                     N
#
#   debt_settlement_flag_date settlement_status settlement_date  \
# 0                       NaN               NaN             NaN
# 1                       NaN               NaN             NaN
# 2                       NaN               NaN             NaN
# 3                       NaN               NaN             NaN
# 4                       NaN               NaN             NaN
#
#   settlement_amount settlement_percentage settlement_term
# 0               NaN                   NaN             NaN
# 1               NaN                   NaN             NaN
# 2               NaN                   NaN             NaN
# 3               NaN                   NaN             NaN
# 4               NaN                   NaN             NaN
#
# [5 rows x 150 columns]

# %% [markdown]
# ***let's check the data***

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421097 entries, 0 to 421096
# Columns: 150 entries, id to settlement_term
# dtypes: float64(112), object(38)
# memory usage: 481.9+ MB

# %%
df.shape
# Out:
# (421097, 150)

# %% [markdown]
# **There are 150 columns. we need to look into this and see if there are columns that we can eliminate to make the job easier and faster. To achieve this, we will do a series of dataset evaluation tasks. I also downloaded the data dictionary that is available for download as well. In order to get a better grasp of what these columns are we will need to look at it.**

# %%
dic_des = pd.read_excel('/Users/hadiardestani/Desktop/website-portfolio/website-portfolio/Data cleaning, Preparation and Feature Engineering/LCDataDictionary.xlsx').dropna()

# %% [markdown]
# **Now I am going to add a description column from my imported data dictionary by creating a data frame that only shows names and the description. Imaging doing a copy and transpose paste of all the columns in the dataset and then doing a VLOOKUP of name to bring in the description next to it.**

# %%
dic_des = dic_des.rename(columns={'LoanStatNew': 'Name'})
df_dtypes = pd.DataFrame(df.dtypes,columns=['dtypes'])
df_dtypes = df_dtypes.reset_index()
df_dtypes['Name'] = df_dtypes['index']
df_dtypes = df_dtypes[['Name','dtypes']]
vlookup = df_dtypes.merge(dic_des, on='Name',how='left')

# %%
vlookup.style.set_properties(subset=['Description'], **{'width': '1000px'})
# Out:
# <style  type="text/css" >
#     #T_04190a8e_ac43_11ea_8c31_0026bb688216row0_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row1_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row2_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row3_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row4_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row5_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row6_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row7_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row8_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row9_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row10_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row11_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row12_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row13_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row14_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row15_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row16_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row17_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row18_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row19_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row20_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row21_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row22_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row23_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row24_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row25_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row26_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row27_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row28_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row29_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row30_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row31_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row32_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row33_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row34_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row35_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row36_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row37_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row38_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row39_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row40_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row41_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row42_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row43_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row44_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row45_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row46_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row47_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row48_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row49_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row50_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row51_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row52_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row53_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row54_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row55_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row56_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row57_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row58_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row59_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row60_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row61_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row62_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row63_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row64_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row65_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row66_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row67_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row68_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row69_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row70_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row71_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row72_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row73_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row74_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row75_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row76_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row77_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row78_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row79_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row80_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row81_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row82_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row83_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row84_col2 {
#             width:  1000px;
#         }    #T_04190a8e_ac43_11ea_8c31_0026bb688216row85_col2 {
#             width:  100

# %% [markdown]
# **Let's start by looking at the columns and their description to see if there are columns that won't contribute to our purpose so we acn remove them. This is time consuming but worth it. After going through them I decided below colomuns can be removed. They were chosen because either they had nothing to do with a brrower paying back the ooan such as Id or member id, or anything that is about feature meaning after the loan is approved, or anything that is bad formatted and is redundant.
# **id / member_id / funded_amnt / funded_amnt_inv / sub_grade / int_rate./ emp_title / issued_d / zip_code / out_prncp  / out_prncp_inv./ total_pymnt / total_pymnt_inv/ total_rec_prncp / total_rec_int/ total_rec_late_fee / recoveries/ collection_recovery_fee/ last_pymnt_d/ last_pymnt_amnt**

# %%
df=df.drop (['id','int_rate','total_pymnt','total_rec_late_fee','member_id','sub_grade','total_pymnt_inv',
             'recoveries','funded_amnt','emp_title','total_rec_prncp','collection_recovery_fee','funded_amnt_inv',
             'issue_d','total_rec_int','last_pymnt_d','zip_code','out_prncp','last_pymnt_amnt','out_prncp_inv',
             'installment','last_credit_pull_d','last_fico_range_high','last_fico_range_low','sec_app_fico_range_low','sec_app_fico_range_high','loan_amnt',
             'next_pymnt_d','num_tl_120dpd_2m','num_tl_30dpd','url','title'],axis=1)

# %% [markdown]
# **Also, there are a few columns that I like to look dipper into them. FICO scores columns. I realized that there are 6 columns for FICO score. fico_range_low, fico_range_high, last_fico_range_low,last_fico_range_high,sec_app_fico_range_low	,sec_app_fico_range_high. It seems that when you apply for a loan Lending club assigns you with a FICO score limit, meaning a lower and higher range. As all the other institutions that borrow money, Lending club updates your score once in a while and marks it by last_. We for sure don't need the 2 columns that gets updated after the loan is approved since they are in the future and don't have anything to do with deciding to approve the loan or not, the same goes for sec_app_fico_range ones. I would like to combine the other 2 columns into one FICO score. Maybe the best way to do it is by getting an average of the 2 number. Let's take a look. **

# %%
df['FICO']=(df['fico_range_high']+df['fico_range_low']) /2

# %%
fico_columns = ['fico_range_low','fico_range_high','FICO']
df[fico_columns].head()
# Out:
#    fico_range_low  fico_range_high   FICO
# 0           700.0            704.0  702.0
# 1           745.0            749.0  747.0
# 2           800.0            804.0  802.0
# 3           680.0            684.0  682.0
# 4           835.0            839.0  837.0

# %%
df=df.drop (['fico_range_low','fico_range_high'],axis=1)

# %% [markdown]
# **let’s first look at the summary of the. Below function was written by Leonardo Ferreira (Lending Club - Insightful Financial EDA), and it perfectly does the summarizing job. There are many other ways of doing that, but I found this function easy and quick.**

# %%
def resumetable(df):
    print(f"Dataset Shape: {df.shape}")
    summary = pd.DataFrame(df.dtypes,columns=['dtypes'])
    summary = summary.reset_index()
    summary['Name'] = summary['index']
    summary = summary[['Name','dtypes']]
    summary['Missing'] = df.isnull().sum().values    
    summary['Uniques'] = df.nunique().values
    summary['First Value'] = df.loc[0].values
    summary['Second Value'] = df.loc[1].values
    summary['Third Value'] = df.loc[2].values

    for name in summary['Name'].value_counts().index:
        summary.loc[summary['Name'] == name, 'Entropy'] = round(stats.entropy(df[name].value_counts(normalize=True), base=2),2) 

    return summary

# %%
resumetable(df)
# Out:
# Dataset Shape: (421097, 117)
#                                            Name   dtypes  Missing  Uniques  \
# 0                                          term   object        2        2
# 1                                         grade   object        2        7
# 2                                    emp_length   object    23819       11
# 3                                home_ownership   object        2        4
# 4                                    annual_inc  float64        2    26903
# 5                           verification_status   object        2        3
# 6                                   loan_status   object        2        7
# 7                                    pymnt_plan   object        2        1
# 8                                          desc   object   421052       34
# 9                                       purpose   object        2       14
# 10                                   addr_state   object        2       49
# 11                                          dti  float64        4     4085
# 12                                  delinq_2yrs  float64        2       26
# 13                             earliest_cr_line   object        2      668
# 14                               inq_last_6mths  float64        2        7
# 15                       mths_since_last_delinq  float64   203964      140
# 16                       mths_since_last_record  float64   346682      121
# 17                                     open_acc  float64        2       73
# 18                                      pub_rec  float64        2       28
# 19                                    revol_bal  float64        2    62072
# 20                                   revol_util   object      164     1211
# 21                                    total_acc  float64        2      126
# 22                          initial_list_status   object        2        2
# 23                   collections_12_mths_ex_med  float64        2       10
# 24                  mths_since_last_major_derog  float64   298368      152
# 25                                  policy_code  float64        2        1
# 26                             application_type   object        2        2
# 27                             annual_inc_joint  float64   420586      308
# 28                                    dti_joint  float64   420588      449
# 29                    verification_status_joint   object   420586        1
# ..                                          ...      ...      ...      ...
# 87                             sec_app_open_acc  float64   421097        0
# 88                           sec_app_revol_util  float64   421097        0
# 89                          sec_app_open_act_il  float64   421097        0
# 90                        sec_app_num_rev_accts  float64   421097        0
# 91             sec_app_chargeoff_within_12_mths  float64   421097        0
# 92           sec_app_collections_12_mths_ex_med  float64   421097        0
# 93          sec_app_mths_since_last_major_derog  float64   421097        0
# 94                                hardship_flag   object     1377        2
# 95                                hardship_type   object   416757        4
# 96                              hardship_reason   object   416757       17
# 97                              hardship_status   object   416757        4
# 98                                deferral_term  float64   416757        4
# 99                              hardship_amount  float64   415382     3199
# 100                         hardship_start_date   object   416757       40
# 101                           hardship_end_date   object   416757       42
# 102                     payment_plan_start_date   object   416757       42
# 103                             hardship_length  float64   416757        4
# 104                                hardship_dpd  float64   416757       35
# 105                        hardship_loan_status   object   416760        9
# 106  orig_projected_additional_accrued_interest  float64   415882     4250
# 107              hardship_payoff_balance_amount  float64   415382     5002
# 108                hardship_last_payment_amount  float64   415382     4342
# 109                        debt_settlement_flag   object        2        2
# 110                   debt_settlement_flag_date   object   407951       58
# 111                           settlement_status   object   407951        3
# 112                             settlement_date   object   407951       61
# 113                           settlement_amount  float64   407951    10417
# 114                       settlement_percentage  float64   407951      980
# 115                             settlement_term  float64   407951       39
# 116                                        FICO  float64        2       38
#
#       First Value        Second Value         Third Value  Entropy
# 0       36 months           36 months           60 months     0.91
# 1               B                   A                   C     2.34
# 2       10+ years           10+ years           10+ years     3.04
# 3        MORTGAGE            MORTGAGE            MORTGAGE     1.38
# 4           42000              109000              112000     8.14
# 5    Not Verified        Not Verified        Not Verified     1.55
# 6      Fully Paid          Fully Paid          Fully Paid     0.96
# 7               n                   n                   n     0.00
# 8             NaN                 NaN                 NaN     4.54
# 9     credit_card  debt_consolidation  debt_consolidation     1.78
# 10             RI                  VA                  AZ     4.85
# 11           34.8               26.02                8.68    11.74
# 12              0                   0                   0     1.07
# 13       Nov-1994            Dec-2001            Nov-1993     8.39
# 14              0                   1                   0     1.48
# 15             75                 NaN                 NaN     6.29
# 16            NaN                 NaN                 NaN     6.63
# 17              8                   9                  17     4.38
# 18              0                   0                   0     0.85
# 19           7034               20862               10711    15.22
# 20          39.1%               54.3%               15.5%     9.86
# 21             18                  19                  27     5.53
# 22              w                   w                   w     0.95
# 23              0                   0                   0     0.14
# 24             75                 NaN                 NaN     6.35
# 25              1                   1                   1     0.00
# 26     Individual          Individual          Individual     0.01
# 27            NaN                 NaN                 NaN     7.87
# 28            NaN                 NaN                 NaN     8.75
# 29            NaN                 NaN                 NaN     0.00
# ..            ...                 ...                 ...      ...
# 87            NaN                 NaN                 NaN     0.00
# 88            NaN                 NaN                 NaN     0.00
# 89            NaN                 NaN                 NaN     0.00
# 90            NaN                 NaN                 NaN     0.00
# 91            NaN                 NaN                 NaN     0.00
# 92            NaN                 NaN                 NaN     0.00
# 93            NaN                 NaN                 NaN     0.00
# 94              N                   N                   N     0.03
# 95            NaN                 NaN                 NaN     1.32
# 96            NaN                 NaN                 NaN     3.27
# 97            NaN                 NaN                 NaN     1.79
# 98            NaN                 NaN                 NaN     1.15
# 99            NaN                 NaN                 NaN     8.86
# 100           NaN                 NaN                 NaN     3.73
# 101           NaN                 NaN                 NaN     4.13
# 102           NaN                 NaN                 NaN     4.10
# 103           NaN                 NaN                 NaN     1.15
# 104           NaN                 NaN                 NaN     3.63
# 105           NaN                 NaN                 NaN     2.60
# 106           NaN                 NaN                 NaN    10.97
# 107           NaN                 NaN                 NaN    11.32
# 108           NaN                 NaN                 NaN    11.78
# 109             N                   N                   N     0.20
# 110           NaN                 NaN                 NaN     5.28
# 111           NaN                 NaN                 NaN     1.16
# 112           NaN                 NaN                 NaN     5.32
# 113           NaN                 NaN                 NaN    13.18
# 114           NaN                 NaN                 NaN     4.24
# 115           NaN                 NaN                 NaN     3.60
# 116           702                 747                 802     4.26
#
# [117 rows x 8 columns]

# %% [markdown]
# **Now that we have 118 columns or features. let’s start by handling missing values and first removing the columns that have too many null values that practically we won't be able to use them. As it can be seen in the summary query result from row 100 to 129 the total number of missing values are way more than the total number of data in one column. So, we might be able to remove some of these columns. Let’s dig in.**

# %%
#Let's see how many columns contain null values and how many don't.
print("columns with missing values:", len(df.columns[df.isna().any()]))
print("columns with no missing values:", len(df.columns[df.notna().all()]))
print("All columns in the dataframe:",len(df.columns))
# Out:
# columns with missing values: 117
# columns with no missing values: 0
# All columns in the dataframe: 117

# %% [markdown]
# **Now let’s calculate the Percentage of missing values in each column. I am going to modify my summary function and try to use is to calculate this**

# %%
null_v = df.isnull().sum()
null_v_per = round (100 * df.isnull().sum() / len(df),2)
#now let's create table view of the the two side by side
missing_value_table = pd.DataFrame({'Count': null_v, 'Percent': null_v_per })
missing_value_table[(missing_value_table['Count']>2) & (missing_value_table['Percent']>50)].sort_values('Percent',ascending=False)
# Out:
#                                              Count  Percent
# sec_app_open_acc                            421097   100.00
# revol_bal_joint                             421097   100.00
# sec_app_mths_since_last_major_derog         421097   100.00
# sec_app_collections_12_mths_ex_med          421097   100.00
# sec_app_chargeoff_within_12_mths            421097   100.00
# sec_app_num_rev_accts                       421097   100.00
# sec_app_open_act_il                         421097   100.00
# sec_app_revol_util                          421097   100.00
# sec_app_mort_acc                            421097   100.00
# sec_app_inq_last_6mths                      421097   100.00
# sec_app_earliest_cr_line                    421097   100.00
# desc                                        421052    99.99
# annual_inc_joint                            420586    99.88
# dti_joint                                   420588    99.88
# verification_status_joint                   420586    99.88
# hardship_dpd                                416757    98.97
# hardship_status                             416757    98.97
# hardship_type                               416757    98.97
# deferral_term                               416757    98.97
# hardship_start_date                         416757    98.97
# hardship_end_date                           416757    98.97
# payment_plan_start_date                     416757    98.97
# hardship_length                             416757    98.97
# hardship_reason                             416757    98.97
# hardship_loan_status                        416760    98.97
# orig_projected_additional_accrued_interest  415882    98.76
# hardship_payoff_balance_amount              415382    98.64
# hardship_last_payment_amount                415382    98.64
# hardship_amount                             415382    98.64
# debt_settlement_flag_date                   407951    96.88
# settlement_status                           407951    96.88
# settlement_date                             407951    96.88
# settlement_amount                           407951    96.88
# settlement_percentage                       407951    96.88
# settlement_term                             407951    96.88
# il_util                                     402480    95.58
# mths_since_rcnt_il                          400287    95.06
# open_rv_12m                                 399725    94.92
# open_rv_24m                                 399725    94.92
# open_act_il                                 399725    94.92
# open_il_12m                                 399725    94.92
# open_il_24m                                 399725    94.92
# total_bal_il                                399725    94.92
# open_acc_6m                                 399725    94.92
# inq_last_12m                                399725    94.92
# total_cu_tl                                 399725    94.92
# inq_fi                                      399725    94.92
# all_util                                    399725    94.92
# max_bal_bc                                  399725    94.92
# mths_since_last_record                      346682    82.33
# mths_since_recent_bc_dlq                    312497    74.21
# mths_since_last_major_derog                 298368    70.85
# mths_since_recent_revol_delinq              269360    63.97

# %% [markdown]
# **As it can be seen there are column or features withn more than 80% missing or null value in them. These feature won't be helping us. So I will drrop any column that has a null value percentage of above %80**

# %%
#too_many_null = [i for i in df.count()<128260 *0.80]
#df.drop(df.columns[too_many_null],axis=1,inplace=True)

df = df.dropna(axis=1, thresh=int(0.80*len(df)))

# %%
print("columns with missing values:", len(df.columns[df.isna().any()]))
print("columns with no missing values:", len(df.columns[df.notna().all()]))
print("All columns in the dataframe:",len(df.columns))
# Out:
# columns with missing values: 63
# columns with no missing values: 0
# All columns in the dataframe: 63

# %%
#let's check the summary again
resumetable(df)
# Out:
# Dataset Shape: (421097, 63)
#                           Name   dtypes  Missing  Uniques   First Value  \
# 0                         term   object        2        2     36 months
# 1                        grade   object        2        7             B
# 2                   emp_length   object    23819       11     10+ years
# 3               home_ownership   object        2        4      MORTGAGE
# 4                   annual_inc  float64        2    26903         42000
# 5          verification_status   object        2        3  Not Verified
# 6                  loan_status   object        2        7    Fully Paid
# 7                   pymnt_plan   object        2        1             n
# 8                      purpose   object        2       14   credit_card
# 9                   addr_state   object        2       49            RI
# 10                         dti  float64        4     4085          34.8
# 11                 delinq_2yrs  float64        2       26             0
# 12            earliest_cr_line   object        2      668      Nov-1994
# 13              inq_last_6mths  float64        2        7             0
# 14                    open_acc  float64        2       73             8
# 15                     pub_rec  float64        2       28             0
# 16                   revol_bal  float64        2    62072          7034
# 17                  revol_util   object      164     1211         39.1%
# 18                   total_acc  float64        2      126            18
# 19         initial_list_status   object        2        2             w
# 20  collections_12_mths_ex_med  float64        2       10             0
# 21                 policy_code  float64        2        1             1
# 22            application_type   object        2        2    Individual
# 23              acc_now_delinq  float64        2        8             0
# 24                tot_coll_amt  float64        2     8350             0
# 25                 tot_cur_bal  float64        2   230329        199696
# 26            total_rev_hi_lim  float64        2    10694         18000
# 27        acc_open_past_24mths  float64        2       47             5
# 28                 avg_cur_bal  float64        2    56003         28528
# 29              bc_open_to_buy  float64     3965    51127          9966
# ..                         ...      ...      ...      ...           ...
# 33          mo_sin_old_il_acct  float64    12256      475           155
# 34        mo_sin_old_rev_tl_op  float64        2      709           253
# 35       mo_sin_rcnt_rev_tl_op  float64        2      241            15
# 36              mo_sin_rcnt_tl  float64        2      168            10
# 37                    mort_acc  float64        2       36             1
# 38        mths_since_recent_bc  float64     3800      426            50
# 39       mths_since_recent_inq  float64    44601       26            10
# 40       num_accts_ever_120_pd  float64        2       35             1
# 41              num_actv_bc_tl  float64        2       31             3
# 42             num_actv_rev_tl  float64        2       46             3
# 43                 num_bc_sats  float64        2       48             3
# 44                   num_bc_tl  float64        2       61             6
# 45                   num_il_tl  float64        2      104             5
# 46               num_op_rev_tl  float64        2       60             5
# 47               num_rev_accts  float64        3       91            11
# 48         num_rev_tl_bal_gt_0  float64        2       43             3
# 49                    num_sats  float64        2       72             8
# 50          num_tl_90g_dpd_24m  float64        2       25             0
# 51          num_tl_op_past_12m  float64        2       28             2
# 52              pct_tl_nvr_dlq  float64        2      547          94.4
# 53            percent_bc_gt_75  float64     4241      186          33.3
# 54        pub_rec_bankruptcies  float64        2       11             0
# 55                   tax_liens  float64        2       25             0
# 56             tot_hi_cred_lim  float64        2   237207        256513
# 57           total_bal_ex_mort  float64        2   128720        113782
# 58              total_bc_limit  float64        2     5097         17000
# 59  total_il_high_credit_limit  float64        2   115868        135513
# 60               hardship_flag   object     1377        2             N
# 61        debt_settlement_flag   object        2        2             N
# 62                        FICO  float64        2       38           702
#
#           Second Value         Third Value  Entropy
# 0            36 months           60 months     0.91
# 1                    A                   C     2.34
# 2            10+ years           10+ years     3.04
# 3             MORTGAGE            MORTGAGE     1.38
# 4               109000              112000     8.14
# 5         Not Verified        Not Verified     1.55
# 6           Fully Paid          Fully Paid     0.96
# 7                    n                   n     0.00
# 8   debt_consolidation  debt_consolidation     1.78
# 9                   VA                  AZ     4.85
# 10               26.02                8.68    11.74
# 11                   0                   0     1.07
# 12            Dec-2001            Nov-1993     8.39
# 13                   1                   0     1.48
# 14                   9                  17     4.38
# 15                   0                   0     0.85
# 16               20862               10711    15.22
# 17               54.3%               15.5%     9.86
# 18                  19                  27     5.53
# 19                   w                   w     0.95
# 20                   0                   0     0.14
# 21                   1                   1     0.00
# 22          Individual          Individual     0.01
# 23                   0                   0     0.05
# 24                   0                   0     2.36
# 25              305781              205067    17.51
# 26               38400               82400     9.90
# 27                   2                   5     3.55
# 28               33976               17089    14.86
# 29               17538               60336    14.20
# ..                 ...                 ...      ...
# 33                 142                 109     7.60
# 34                 168                 265     8.48
# 35                  13                   1     5.14
# 36                  13                   1     4.38
# 37                   3                   4     2.53
# 38                  13                   1     5.99
# 39                   0                  10     4.23
# 40                   0                   0     1.32
# 41                   3                   5     3.07
# 42                   3                   6     3.61
# 43                   5                  12     3.41
# 44                   6                  12     4.12
# 45                   7                   6     4.53
# 46                   5                  15     4.06
# 47                   9                  17     4.90
# 48                   3                   6     3.58
# 49                   9                  16     4.37
# 50                   0                   0     0.41
# 51                   0                   4     2.71
# 52                 100                 100     4.69
# 53                  20                   0     3.89
# 54                   0                   0     0.59
# 55                   0                   0     0.30
# 56              373572              309710    17.26
# 57               68056               36127    16.58
# 58               38400               69800     9.25
# 59               82117               26210    14.70
# 60                   N                   N     0.03
# 61                   N                   N     0.20
# 62                 747                 802     4.26
#
# [63 rows x 8 columns]

# %% [markdown]
# **From above we can see that there are a few columns that have only one unique value. Those also won't be helpful in our modeling. We will dropm them as well.**

# %%
df = df.loc[:,df.apply(pd.Series.nunique) != 1]

# %% [markdown]
# There are also a few columns with more than 1 unique value but one of the unique values has been repeated many times. so, the other ones don’t matter much. That makes these columns similar to the ones with only one unique value. So, we can drop them too. I checked those for columns that had less than 6 unique value and end up with going with the ones with only 4.

# %%
for i in df.columns:
    if (len(df[i].unique())<4):
        print(df[i].value_counts())
        print()
# Out:
#  36 months    283173
#  60 months    137922
# Name: term, dtype: int64
#
# w    267252
# f    153843
# Name: initial_list_status, dtype: int64
#
# Individual    420584
# Joint App        511
# Name: application_type, dtype: int64
#
# N    418202
# Y      1518
# Name: hardship_flag, dtype: int64
#
# N    407949
# Y     13146
# Name: debt_settlement_flag, dtype: int64

# %%
df=df.drop (['debt_settlement_flag','hardship_flag',
'application_type'],axis=1)

# %%
df.shape
# Out:
# (421097, 58)

# %% [markdown]
# **Lets see how many more columns that have more than 2 missding values are left and what is their data type.

# %%
null_v2 = df.isnull().sum()
null_v2_Data_type=null_v2.dtypes
null_v_per2 = round (100 * df.isnull().sum() / len(df),2)
#now let's create table view of the the two side by side
missing_value_table2 = pd.DataFrame({'Count': null_v2, 'Percent': null_v_per2, 'Data_type':null_v2_Data_type })
final_missning=missing_value_table2[missing_value_table2['Count'] >2].sort_values('Percent',ascending=False)
final_missning
# Out:
#                        Count  Percent Data_type
# mths_since_recent_inq  44601    10.59     int64
# emp_length             23819     5.66     int64
# mo_sin_old_il_acct     12256     2.91     int64
# percent_bc_gt_75        4241     1.01     int64
# bc_util                 4229     1.00     int64
# bc_open_to_buy          3965     0.94     int64
# mths_since_recent_bc    3800     0.90     int64
# revol_util               164     0.04     int64
# dti                        4     0.00     int64
# num_rev_accts              3     0.00     int64

# %% [markdown]
# **All 10 above columns with more than 2 missing values have a data type of integer. We can easily find a solution to handel the missing values in this columns. But first let's look through the description and see if there is anything that won't be useful so we can drop.

# %%
final_missning2 = final_missning.reset_index()
final_missning2['Name'] = final_missning2['index']
final_missning2 = final_missning2[['Name','Data_type']]
vlookup2 = final_missning2.merge(dic_des, on='Name',how='left')
vlookup2.style.set_properties(subset=['Description'], **{'width': '1000px'})
# Out:
# <style  type="text/css" >
#     #T_25535ba0_ac43_11ea_8c31_0026bb688216row0_col2 {
#             width:  1000px;
#         }    #T_25535ba0_ac43_11ea_8c31_0026bb688216row1_col2 {
#             width:  1000px;
#         }    #T_25535ba0_ac43_11ea_8c31_0026bb688216row2_col2 {
#             width:  1000px;
#         }    #T_25535ba0_ac43_11ea_8c31_0026bb688216row3_col2 {
#             width:  1000px;
#         }    #T_25535ba0_ac43_11ea_8c31_0026bb688216row4_col2 {
#             width:  1000px;
#         }    #T_25535ba0_ac43_11ea_8c31_0026bb688216row5_col2 {
#             width:  1000px;
#         }    #T_25535ba0_ac43_11ea_8c31_0026bb688216row6_col2 {
#             width:  1000px;
#         }    #T_25535ba0_ac43_11ea_8c31_0026bb688216row7_col2 {
#             width:  1000px;
#         }    #T_25535ba0_ac43_11ea_8c31_0026bb688216row8_col2 {
#             width:  1000px;
#         }    #T_25535ba0_ac43_11ea_8c31_0026bb688216row9_col2 {
#             width:  1000px;
#         }</style>
# <table id="T_25535ba0_ac43_11ea_8c31_0026bb688216" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Name</th>
#         <th class="col_heading level0 col1" >Data_type</th>
#         <th class="col_heading level0 col2" >Description</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_25535ba0_ac43_11ea_8c31_0026bb688216level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_25535ba0_ac43_11ea_8c31_0026bb688216row0_col0" class="data row0 col0" >mths_since_recent_inq</td>
#         <td id="T_25535ba0_ac43_11ea_8c31_0026bb688216row0_col1" class="data row0 col1" >int64</td>
#         <td id="T_25535ba0_ac43_11ea_8c31_0026bb688216row0_col2" class="data row0 col2" >Months since most recent inquiry.</td>
#     </tr>    <tr>
#         <th id="T_25535ba0_ac43_11ea_8c31_0026bb688216level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_25535ba0_ac43_11ea_8c31_0026bb688216row1_col0" class="data row1 col0" >emp_length</td>
#         <td id="T_25535ba0_ac43_11ea_8c31_0026bb688216row1_col1" class="data row1 col1" >int64</td>
#         <td id="T_25535ba0_ac43_11ea_8c31_0026bb688216row1_col2" class="data row1 col2" >Employment length in years. Possible values are between 0 and 10 where 0 means less than one year and 10 means ten or more years.</td>
#     </tr>    <tr>
#         <th id="T_25535ba0_ac43_11ea_8c31_0026bb688216level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_25535ba0_ac43_11ea_8c31_0026bb688216row2_col0" class="data row2 col0" >mo_sin_old_il_acct</td>
#         <td id="T_25535ba0_ac43_11ea_8c31_0026bb688216row2_col1" class="data row2 col1" >int64</td>
#         <td id="T_25535ba0_ac43_11ea_8c31_0026bb688216row2_col2" class="data row2 col2" >Months since oldest bank installment account opened</td>
#     </tr>    <tr>
#         <th id="T_25535ba0_ac43_11ea_8c31_0026bb688216level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_25535ba0_ac43_11ea_8c31_0026bb688216row3_col0" class="data row3 col0" >percent_bc_gt_75</td>
#         <td id="T_25535ba0_ac43_11ea_8c31_0026bb688216row3_col1" class="data row3 col1" >int64</td>
#         <td id="T_25535ba0_ac43_11ea_8c31_0026bb688216row3_col2" class="data row3 col2" >Percentage of all bankcard accounts > 75% of limit.</td>
#     </tr>    <tr>
#         <th id="T_25535ba0_ac43_11ea_8c31_0026bb688216level0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_25535ba0_ac43_11ea_8c31_0026bb688216row4_col0" class="data row4 col0" >bc_util</td>
#         <td id="T_25535ba0_ac43_11ea_8c31_0026bb688216row4_col1" class="data row4 col1" >int64</td>
#         <td id="T_25535ba0_ac43_11ea_8c31_0026bb688216row4_col2" class="data row4 col2" >Ratio of total current balance to high credit/credit limit for all bankcard accounts.</td>
#     </tr>    <tr>
#         <th id="T_25535ba0_ac43_11ea_8c31_0026bb688216level0_row5" class="row_heading level0 row5" >5</th>
#         <td id="T_25535ba0_ac43_11ea_8c31_0026bb688216row5_col0" class="data row5 col0" >bc_open_to_buy</td>
#         <td id="T_25535ba0_ac43_11ea_8c31_0026bb688216row5_col1" class="data row5 col1" >int64</td>
#         <td id="T_25535ba0_ac43_11ea_8c31_0026bb688216row5_col2" class="data row5 col2" >Total open to buy on revolving bankcards.</td>
#     </tr>    <tr>
#         <th id="T_25535ba0_ac43_11ea_8c31_0026bb688216level0_row6" class="row_heading level0 row6" >6</th>
#         <td id="T_25535ba0_ac43_11ea_8c31_0026bb688216row6_col0" class="data row6 col0" >mths_since_recent_bc</td>
#         <td id="T_25535ba0_ac43_11ea_8c31_0026bb688216row6_col1" class="data row6 col1" >int64</td>
#         <td id="T_25535ba0_ac43_11ea_8c31_0026bb688216row6_col2" class="data row6 col2" >Months since most recent bankcard account opened.</td>
#     </tr>    <tr>
#         <th id="T_25535ba0_ac43_11ea_8c31_0026bb688216level0_row7" class="row_heading level0 row7" >7</th>
#         <td id="T_25535ba0_ac43_11ea_8c31_0026bb688216row7_col0" class="data row7 col0" >revol_util</td>
#         <td id="T_25535ba0_ac43_11ea_8c31_0026bb688216row7_col1" class="data row7 col1" >int64</td>
#         <td id="T_25535ba0_ac43_11ea_8c31_0026bb688216row7_col2" class="data row7 col2" >Revolving line utilization rate, or the amount of credit the borrower is using relative to all available revolving credit.</td>
#     </tr>    <tr>
#         <th id="T_25535ba0_ac43_11ea_8c31_0026bb688216level0_row8" class="row_heading level0 row8" >8</th>
#         <td id="T_25535ba0_ac43_11ea_8c31_0026bb688216row8_col0" class="data row8 col0" >dti</td>
#         <td id="T_25535ba0_ac43_11ea_8c31_0026bb688216row8_col1" class="data row8 col1" >int64</td>
#         <td id="T_25535ba0_ac43_11ea_8c31_0026bb688216row8_col2" class="data row8 col2" >A ratio calculated using the borrower’s total monthly debt payments on the total debt obligations, excluding mortgage and the requested LC loan, divided by the borrower’s self-reported monthly income.</td>
#     </tr>    <tr>
#         <th id="T_25535ba0_ac43_11ea_8c31_0026bb688216level0_row9" class="row_heading level0 row9" >9</th>
#         <td id="T_25535ba0_ac43_11ea_8c31_0026bb688216row9_col0" class="data row9 col0" >num_rev_accts</td>
#         <td id="T_25535ba0_ac43_11ea_8c31_0026bb688216row9_col1" class="data row9 col1" >int64</td>
#         <td id="T_25535ba0_ac43_11ea_8c31_0026bb688216row9_col2" class="data row9 col2" >Number of revolving accounts</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# ***AlL the above seems to be usful, therefore we proceed to imputation. Imputation simply means replacing the missing values with an estimate. There are many different approaches and technics to imputation. There are only 3 columns that have a missing value percentage of grater than 3 % of total data. I will imputate those first.

# %%
#mths_since_recent_inq= Months since most recent inquiry. and mo_sin_old_il_acct: Months since oldest bank installment account opened. For these columns I will use
#fill with max value since if there is no value this means that there has never been a recent inquiry  or oldest bank installment
#so the month since that time would be max. For this ratio column I will replace missing values the mean value of the column
df['mths_since_recent_inq'].fillna(df['mths_since_recent_inq'].max(),inplace=True)
df['mo_sin_old_il_acct'].fillna(df['mo_sin_old_il_acct'].max(),inplace=True)

# %%
##emp_length= Employment length in years. Possible values are between 0 and 10 where 0 means less than one year and 10
#means ten or more years. First we need to fix the records with < 1 year and 10+ years and re[lace them with 0 years
#and 11 years according to the description. Then we will need to fix the data type to float. now We will replace the 
#missimng values with 0 assuming that the borrower didn't have any employmnet history or had it for less than a year.
#Also, I'll be using regex to extract the number of years from all of the data.
df['emp_length'].fillna(value=0,inplace=True)
df['emp_length'].replace(to_replace='[^0-11]+', value='', inplace=True, regex=True)

# %%
#Let's just check if it makes sense. It appear that it makes sense. The browser with 10 or higher years of employment 
#got a loan approval more than the others.
df['emp_length'].value_counts().sort_values().plot(kind='bar',figsize=(15,10))
plt.title('Number of loans distributed by Employment Years',fontsize=20)
plt.xlabel('Number of loans',fontsize=15)
plt.ylabel('Years worked',fontsize=15);

# %% [markdown]
# For all other columns that have missing vaue perncentage of 3 or less than 3% of total values,Since we have enough data to work on I am not going to use any of the imputation technics here. For simlicity I will just drop/delete the rows wehre there is a missing value.

# %%
## dropping the null rows since we have sufficient amount of data and there is no need to fill the null values.
df.dropna(axis=0,inplace=True)

# %%
df.isnull().sum()
# Out:
# term                          0
# grade                         0
# emp_length                    0
# home_ownership                0
# annual_inc                    0
# verification_status           0
# loan_status                   0
# purpose                       0
# addr_state                    0
# dti                           0
# delinq_2yrs                   0
# earliest_cr_line              0
# inq_last_6mths                0
# open_acc                      0
# pub_rec                       0
# revol_bal                     0
# revol_util                    0
# total_acc                     0
# initial_list_status           0
# collections_12_mths_ex_med    0
# acc_now_delinq                0
# tot_coll_amt                  0
# tot_cur_bal                   0
# total_rev_hi_lim              0
# acc_open_past_24mths          0
# avg_cur_bal                   0
# bc_open_to_buy                0
# bc_util                       0
# chargeoff_within_12_mths      0
# delinq_amnt                   0
# mo_sin_old_il_acct            0
# mo_sin_old_rev_tl_op          0
# mo_sin_rcnt_rev_tl_op         0
# mo_sin_rcnt_tl                0
# mort_acc                      0
# mths_since_recent_bc          0
# mths_since_recent_inq         0
# num_accts_ever_120_pd         0
# num_actv_bc_tl                0
# num_actv_rev_tl               0
# num_bc_sats                   0
# num_bc_tl                     0
# num_il_tl                     0
# num_op_rev_tl                 0
# num_rev_accts                 0
# num_rev_tl_bal_gt_0           0
# num_sats                      0
# num_tl_90g_dpd_24m            0
# num_tl_op_past_12m            0
# pct_tl_nvr_dlq                0
# percent_bc_gt_75              0
# pub_rec_bankruptcies          0
# tax_liens                     0
# tot_hi_cred_lim               0
# total_bal_ex_mort             0
# total_bc_limit                0
# total_il_high_credit_limit    0
# FICO                          0
# dtype: int64

# %%
df.shape
# Out:
# (416589, 58)

# %% [markdown]
# # Feature Engineering
# Feature Engineering goes hand in hand with Data cleaning and preparation. Meaning that we may have already done some Feature Engineering while we were performing Data cleaning and preparation. Here we will deep dive into it and finish our dataset, so it is ready for our Machin learning modeling. First let's pick and prepare our Target column/feature.

# %% [markdown]
# **The main goal of these practice is to model an algorithm that can most accurately predict whether if a potential borrower would be able to pay off or will default who will pay off a loan and who will default. The only column that would reflect this would be loan status. So let's look the column loan_status.

# %%
df['loan_status'].value_counts()
# Out:
# Fully Paid            319697
# Charged Off            78775
# Current                17358
# Late (31-120 days)       383
# In Grace Period          284
# Late (16-30 days)         75
# Default                   17
# Name: loan_status, dtype: int64

# %% [markdown]
# **From Lending club website explanation, we can conclude that Fully Paid and Charged Off (We will merge 'Charged off' and 'Default' into one category of default) are our main goals. We won't be using any loan status indicating that the loan is ongoing or in progress, because obviously we can't predict based on something that hasn't reached its final status. So, we will be ignoring those and will be turn Fully Paid and Charged Off into binary of 1 and 0.

# %%
df=df[df['loan_status'].isin(['Charged Off', 'Fully Paid', 'Default'])]

# %%
mapping={'loan_status':{'Fully Paid': 1, 'Charged Off': 0 , 'Default': 0}}

# %%
df=df.replace(mapping)

# %%
df['loan_status'].value_counts()
# Out:
# 1    319697
# 0     78792
# Name: loan_status, dtype: int64

# %%
#EDD of loan staus
fig, axs = plt.subplots(1,2,figsize=(14,7))
sns.countplot(x='loan_status',data=df,ax=axs[0])
axs[0].set_title("Loan status by count")
df.loan_status.value_counts().plot(kind='pie', ax=axs[1],autopct='%1.2f%%')
axs[1].set_title("Loan status by %")
plt.show()

# %% [markdown]
# **From above we can tell that we are facing a imbalanced dataset.

# %%
resumetable(df).head(20)
# Out:
# Dataset Shape: (398489, 58)
#                           Name   dtypes  Missing  Uniques   First Value  \
# 0                         term   object        0        2     36 months
# 1                        grade   object        0        7             B
# 2                   emp_length   object        0        4            10
# 3               home_ownership   object        0        4      MORTGAGE
# 4                   annual_inc  float64        0    25605         42000
# 5          verification_status   object        0        3  Not Verified
# 6                  loan_status    int64        0        2             1
# 7                      purpose   object        0       14   credit_card
# 8                   addr_state   object        0       49            RI
# 9                          dti  float64        0     4069          34.8
# 10                 delinq_2yrs  float64        0       26             0
# 11            earliest_cr_line   object        0      667      Nov-1994
# 12              inq_last_6mths  float64        0        7             0
# 13                    open_acc  float64        0       73             8
# 14                     pub_rec  float64        0       27             0
# 15                   revol_bal  float64        0    60677          7034
# 16                  revol_util   object        0     1201         39.1%
# 17                   total_acc  float64        0      125            18
# 18         initial_list_status   object        0        2             w
# 19  collections_12_mths_ex_med  float64        0        9             0
#
#           Second Value         Third Value  Entropy
# 0            36 months           60 months     0.88
# 1                    A                   C     2.34
# 2                   10                  10     1.69
# 3             MORTGAGE            MORTGAGE     1.38
# 4               109000              112000     8.13
# 5         Not Verified        Not Verified     1.55
# 6                    1                   1     0.72
# 7   debt_consolidation  debt_consolidation     1.79
# 8                   VA                  AZ     4.84
# 9                26.02                8.68    11.74
# 10                   0                   0     1.06
# 11            Dec-2001            Nov-1993     8.39
# 12                   1                   0     1.49
# 13                   9                  17     4.37
# 14                   0                   0     0.86
# 15               20862               10711    15.20
# 16               54.3%               15.5%     9.86
# 17                  19                  27     5.53
# 18                   w                   w     0.95
# 19                   0                   0     0.14

# %% [markdown]
# **Notice that earliest_cr_line and revol_util are 2 columns that need formatting.

# %%
df['revol_util'] = df['revol_util'].str.rstrip('%').astype('float')

# %%
df['earliest_cr_line'] = pd.to_datetime(df['earliest_cr_line'], infer_datetime_format=True)

# %%
resumetable(df).head(20)
# Out:
# Dataset Shape: (398489, 58)
#                           Name          dtypes  Missing  Uniques  \
# 0                         term          object        0        2
# 1                        grade          object        0        7
# 2                   emp_length          object        0        4
# 3               home_ownership          object        0        4
# 4                   annual_inc         float64        0    25605
# 5          verification_status          object        0        3
# 6                  loan_status           int64        0        2
# 7                      purpose          object        0       14
# 8                   addr_state          object        0       49
# 9                          dti         float64        0     4069
# 10                 delinq_2yrs         float64        0       26
# 11            earliest_cr_line  datetime64[ns]        0      667
# 12              inq_last_6mths         float64        0        7
# 13                    open_acc         float64        0       73
# 14                     pub_rec         float64        0       27
# 15                   revol_bal         float64        0    60677
# 16                  revol_util         float64        0     1201
# 17                   total_acc         float64        0      125
# 18         initial_list_status          object        0        2
# 19  collections_12_mths_ex_med         float64        0        9
#
#             First Value         Second Value          Third Value  Entropy
# 0             36 months            36 months            60 months     0.88
# 1                     B                    A                    C     2.34
# 2                    10                   10                   10     1.69
# 3              MORTGAGE             MORTGAGE             MORTGAGE     1.38
# 4                 42000               109000               112000     8.13
# 5          Not Verified         Not Verified         Not Verified     1.55
# 6                     1                    1                    1     0.72
# 7           credit_card   debt_consolidation   debt_consolidation     1.79
# 8                    RI                   VA                   AZ     4.84
# 9                  34.8                26.02                 8.68    11.74
# 10                    0                    0                    0     1.06
# 11  1994-11-01 00:00:00  2001-12-01 00:00:00  1993-11-01 00:00:00     8.39
# 12                    0                    1                    0     1.49
# 13                    8                    9                   17     4.37
# 14                    0                    0                    0     0.86
# 15                 7034                20862                10711    15.20
# 16                 39.1                 54.3                 15.5     9.86
# 17                   18                   19                   27     5.53
# 18                    w                    w                    w     0.95
# 19                    0                    0                    0     0.14

# %% [markdown]
# **We are almost done. We just need a few more fixes that we will get them done by performing Data Transformation. <a href='https://developers.google.com/machine-learning/data-prep/transform/introduction'> Here</a> is good resource for Data Transformation, why we need to perform it and how? We usually perform Data transformation before training our data for our model. We do that to transform our data to account for any skewness in the variable distribution. <a href='https://towardsdatascience.com/data-preparation-for-machine-learning-cleansing-transformation-feature-engineering-d2334079b06d'> Here</a> is another good short read on Data Transformation.

# %%
#for our numerical values we will use boxcox transformation to transform our numerical data into normally distributed data.
from scipy.stats import boxcox
numerical = df.columns[df.dtypes == 'float64']
for i in numerical:
    if df[i].min() > 0:
        transformed, lamb = boxcox(df.loc[df[i].notnull(), i])
        if np.abs(1 - lamb) > 0.02:
            df.loc[df[i].notnull(), i] = transformed

# %% [markdown]
# ** Now that our numerical data is normalized we can move on to our categorical data trsnformation.

# %% [markdown]
# ***Still working on this project. come back for update
