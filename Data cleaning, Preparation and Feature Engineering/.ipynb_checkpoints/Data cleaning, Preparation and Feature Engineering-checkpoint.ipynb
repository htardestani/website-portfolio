# %% [markdown]
# ___
# [Home- go back to hadardestani.com](http://hadiardestani.com/)
# ___
# # Data Cleaning and Preparation
#
# A few years ago I borrowed some money from Lending club while I was in school and needed some money. I was very happy with the process and how fast everything worked out. And of course, I paid it off to the last penny. But this is not always the case. Some people default on their loans. How does lending club trust you to borrow money? Of course, they use their past Data, consumer Data, and statistics to determine what is the probability of a potential borrower to pay back in full, and based on their formula they approve or reject the request. I will try to download publically available data from their website and try to create a model that will help predict whether if a potential borrower will pay back in full or not.
#
# I will be using their data from 2019 Q4 (I could download the whole year or even a few years of data but it would be really hard on my machine running big datasets. This smaller dataset will serve the purpose here!) and try to classify and predict whether or not the borrower paid back their loan in full. I downloaded the data from [here](https://www.lendingclub.com/info/download-data.action) (of course I had a username and password since I once was a browser so I just had to reset my password.) At the end of this practice I will download the end result dataset so I can use it for modeling an algorithm in another post.

# %% [markdown]
# # Libraries
#
# ***Let's first import the usual libraries***

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
# %matplotlib inline

# %% [markdown]
# ## The Data
#
# ***I am going to use pandas to import my CSV file***

# %%
lending_club = pd.read_csv('/Users/hadiardestani/Desktop/website-portfolio/website-portfolio/Data cleaning, Preparation and Feature Engineering/LoanStats_securev1_2019Q4.csv',skiprows=1,low_memory=False)

# %%
#I am going to work off of a copy of the data frame, so my machine doesn't have to re-read the entire data frame every time.
#this will save me some memory.
df = lending_club.copy(deep=True)
df.head()
# Out:
#           id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  163477201        NaN     5000.0       5000.0           5000.0   36 months
# 1  164027473        NaN    20000.0      20000.0          20000.0   36 months
# 2  164137439        NaN    33000.0      33000.0          33000.0   60 months
# 3  162948736        NaN    19000.0      19000.0          18975.0   36 months
# 4  164131732        NaN    15000.0      15000.0          15000.0   36 months
#
#   int_rate  installment grade sub_grade       ...         \
# 0   17.74%       180.12     C        C5       ...
# 1   12.40%       668.12     B        B4       ...
# 2   15.24%       789.24     C        C2       ...
# 3    6.46%       581.99     A        A1       ...
# 4    7.02%       463.30     A        A2       ...
#
#   orig_projected_additional_accrued_interest hardship_payoff_balance_amount  \
# 0                                        NaN                            NaN
# 1                                     393.88                       19282.07
# 2                                        NaN                            NaN
# 3                                        NaN                            NaN
# 4                                        NaN                            NaN
#
#   hardship_last_payment_amount  debt_settlement_flag  \
# 0                          NaN                     N
# 1                       668.12                     N
# 2                          NaN                     N
# 3                          NaN                     N
# 4                          NaN                     N
#
#   debt_settlement_flag_date settlement_status settlement_date  \
# 0                       NaN               NaN             NaN
# 1                       NaN               NaN             NaN
# 2                       NaN               NaN             NaN
# 3                       NaN               NaN             NaN
# 4                       NaN               NaN             NaN
#
#   settlement_amount settlement_percentage  settlement_term
# 0               NaN                   NaN              NaN
# 1               NaN                   NaN              NaN
# 2               NaN                   NaN              NaN
# 3               NaN                   NaN              NaN
# 4               NaN                   NaN              NaN
#
# [5 rows x 150 columns]

# %% [markdown]
# ***let's check the data***

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128260 entries, 0 to 128259
# Columns: 150 entries, id to settlement_term
# dtypes: float64(112), object(38)
# memory usage: 146.8+ MB

# %%
df.shape
# Out:
# (128260, 150)

# %% [markdown]
# **There are 150 columns. we need to look into this and see if there are columns that we can eliminate to make the job easier and faster. To achieve this, we will do a series of dataset evaluation tasks. I also downloaded the data dictionary that is available for download as well. In order to get a better grasp of what these columns are we will need to look at it.**

# %%
dic_des = pd.read_excel('/Users/hadiardestani/Desktop/website-portfolio/website-portfolio/Data cleaning, Preparation and Feature Engineering/LCDataDictionary.xlsx').dropna()

# %% [markdown]
# **Now I am going to add a description column from my imported data dictionary by creating a data frame that only shows names and the description. Imaging doing a copy and transpose paste of all the columns in the dataset and then doing a VLOOKUP of name to bring in the description next to it.**

# %%
dic_des = dic_des.rename(columns={'LoanStatNew': 'Name'})
df_dtypes = pd.DataFrame(df.dtypes,columns=['dtypes'])
df_dtypes = df_dtypes.reset_index()
df_dtypes['Name'] = df_dtypes['index']
df_dtypes = df_dtypes[['Name','dtypes']]
vlookup = df_dtypes.merge(dic_des, on='Name',how='left')

# %%
vlookup.style.set_properties(subset=['Description'], **{'width': '1000px'})
# Out:
# <style  type="text/css" >
#     #T_19217806_ab73_11ea_b1cd_0026bb688216row0_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row1_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row2_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row3_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row4_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row5_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row6_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row7_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row8_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row9_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row10_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row11_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row12_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row13_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row14_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row15_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row16_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row17_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row18_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row19_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row20_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row21_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row22_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row23_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row24_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row25_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row26_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row27_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row28_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row29_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row30_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row31_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row32_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row33_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row34_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row35_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row36_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row37_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row38_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row39_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row40_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row41_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row42_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row43_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row44_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row45_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row46_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row47_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row48_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row49_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row50_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row51_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row52_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row53_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row54_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row55_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row56_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row57_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row58_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row59_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row60_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row61_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row62_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row63_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row64_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row65_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row66_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row67_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row68_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row69_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row70_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row71_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row72_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row73_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row74_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row75_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row76_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row77_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row78_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row79_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row80_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row81_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row82_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row83_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row84_col2 {
#             width:  1000px;
#         }    #T_19217806_ab73_11ea_b1cd_0026bb688216row85_col2 {
#             width:  100

# %% [markdown]
# **Let's start by looking at the columns and their description to see if there are columns that won't contribute to our purpose so we acn remove them. This is time consuming but worth it. After going through them I decided below colomuns can be removed. They were chosen because either they had nothing to do with a brrower paying back the ooan such as Id or member id, or anything that is about feature meaning after the loan is approved, or anything that is bad formatted and is redundant.
# **id / member_id / funded_amnt / funded_amnt_inv / sub_grade / int_rate./ emp_title / issued_d / zip_code / out_prncp  / out_prncp_inv./ total_pymnt / total_pymnt_inv/ total_rec_prncp / total_rec_int/ total_rec_late_fee / recoveries/ collection_recovery_fee/ last_pymnt_d/ last_pymnt_amnt**

# %%
df=df.drop (['id','int_rate','total_pymnt','total_rec_late_fee','member_id','sub_grade','total_pymnt_inv',
             'recoveries','funded_amnt','emp_title','total_rec_prncp','collection_recovery_fee','funded_amnt_inv',
             'issue_d','total_rec_int','last_pymnt_d','zip_code','out_prncp','last_pymnt_amnt','out_prncp_inv',
             'installment','last_credit_pull_d','last_fico_range_high','last_fico_range_low','sec_app_fico_range_low','sec_app_fico_range_high','loan_amnt',
             'next_pymnt_d','num_tl_120dpd_2m','num_tl_30dpd','url'],axis=1)

# %% [markdown]
# **Also, there are a few columns that I like to look dipper into them. FICO scores columns. I realized that there are 6 columns for FICO score. fico_range_low, fico_range_high, last_fico_range_low,last_fico_range_high,sec_app_fico_range_low	,sec_app_fico_range_high. It seems that when you apply for a loan Lending club assigns you with a FICO score limit, meaning a lower and higher range. As all the other institutions that borrow money, Lending club updates your score once in a while and marks it by last_. We for sure don't need the 2 columns that gets updated after the loan is approved since they are in the future and don't have anything to do with deciding to approve the loan or not, the same goes for sec_app_fico_range ones. I would like to combine the other 2 columns into one FICO score. Maybe the best way to do it is by getting an average of the 2 number. Let's take a look. **

# %%
df['FICO']=(df['fico_range_high']+df['fico_range_low']) /2

# %%
fico_columns = ['fico_range_low','fico_range_high','FICO']
df[fico_columns].head()
# Out:
#    fico_range_low  fico_range_high   FICO
# 0           685.0            689.0  687.0
# 1           665.0            669.0  667.0
# 2           695.0            699.0  697.0
# 3           785.0            789.0  787.0
# 4           770.0            774.0  772.0

# %%
df=df.drop (['fico_range_low','fico_range_high'],axis=1)

# %% [markdown]
# **let’s first look at the summary of the. Below function was written by Leonardo Ferreira (Lending Club - Insightful Financial EDA), and it perfectly does the summarizing job. There are many other ways of doing that, but I found this function easy and quick.**

# %%
def resumetable(df):
    print(f"Dataset Shape: {df.shape}")
    summary = pd.DataFrame(df.dtypes,columns=['dtypes'])
    summary = summary.reset_index()
    summary['Name'] = summary['index']
    summary = summary[['Name','dtypes']]
    summary['Missing'] = df.isnull().sum().values    
    summary['Uniques'] = df.nunique().values
    summary['First Value'] = df.loc[0].values
    summary['Second Value'] = df.loc[1].values
    summary['Third Value'] = df.loc[2].values

    for name in summary['Name'].value_counts().index:
        summary.loc[summary['Name'] == name, 'Entropy'] = round(stats.entropy(df[name].value_counts(normalize=True), base=2),2) 

    return summary

# %%
resumetable(df)
# Out:
# Dataset Shape: (128260, 118)
#                                            Name   dtypes  Missing  Uniques  \
# 0                                          term   object        2        2
# 1                                         grade   object        2        4
# 2                                    emp_length   object    11233       11
# 3                                home_ownership   object        2        4
# 4                                    annual_inc  float64        2    10082
# 5                           verification_status   object        2        3
# 6                                   loan_status   object        2        7
# 7                                    pymnt_plan   object        2        1
# 8                                          desc  float64   128260        0
# 9                                       purpose   object        2       12
# 10                                        title   object        2       12
# 11                                   addr_state   object        2       50
# 12                                          dti  float64      233     6624
# 13                                  delinq_2yrs  float64        2       21
# 14                             earliest_cr_line   object        2      647
# 15                               inq_last_6mths  float64        2        6
# 16                       mths_since_last_delinq  float64    72117      144
# 17                       mths_since_last_record  float64   115316      112
# 18                                     open_acc  float64        2       70
# 19                                      pub_rec  float64        2        6
# 20                                    revol_bal  float64        2    42986
# 21                                   revol_util   object      191     1074
# 22                                    total_acc  float64        2      118
# 23                          initial_list_status   object        2        2
# 24                   collections_12_mths_ex_med  float64        2        6
# 25                  mths_since_last_major_derog  float64    99974      152
# 26                                  policy_code  float64        2        1
# 27                             application_type   object        2        2
# 28                             annual_inc_joint  float64   112120     3356
# 29                                    dti_joint  float64   112120     3537
# ..                                          ...      ...      ...      ...
# 88                             sec_app_open_acc  float64   112120       58
# 89                           sec_app_revol_util  float64   112381     1066
# 90                          sec_app_open_act_il  float64   112120       34
# 91                        sec_app_num_rev_accts  float64   112120       76
# 92             sec_app_chargeoff_within_12_mths  float64   112120       12
# 93           sec_app_collections_12_mths_ex_med  float64   112120        9
# 94          sec_app_mths_since_last_major_derog  float64   123235      113
# 95                                hardship_flag   object     3270        2
# 96                                hardship_type   object   112410        2
# 97                              hardship_reason   object   112411       13
# 98                              hardship_status   object   112410        2
# 99                                deferral_term  float64   112410        4
# 100                             hardship_amount  float64   109142     1731
# 101                         hardship_start_date   object   112410        3
# 102                           hardship_end_date   object   112410        7
# 103                     payment_plan_start_date   object   112410        7
# 104                             hardship_length  float64   112410        4
# 105                                hardship_dpd  float64   112410       37
# 106                        hardship_loan_status   object   112411        3
# 107  orig_projected_additional_accrued_interest  float64   109142    14554
# 108              hardship_payoff_balance_amount  float64   109142    18314
# 109                hardship_last_payment_amount  float64   109142     7188
# 110                        debt_settlement_flag   object        2        2
# 111                   debt_settlement_flag_date   object   128258        1
# 112                           settlement_status   object   128258        1
# 113                             settlement_date   object   128258        1
# 114                           settlement_amount  float64   128258        2
# 115                       settlement_percentage  float64   128258        1
# 116                             settlement_term  float64   128258        1
# 117                                        FICO  float64        2       38
#
#             First Value    Second Value              Third Value  Entropy
# 0             36 months       36 months                60 months     0.92
# 1                     C               B                        C     1.96
# 2               2 years        < 1 year                10+ years     3.05
# 3                  RENT            RENT                 MORTGAGE     1.41
# 4                 50000           13000                    84000     8.04
# 5       Source Verified        Verified          Source Verified     1.37
# 6               Current         Current                  Current     0.53
# 7                     n               n                        n     0.00
# 8                   NaN             NaN                      NaN     0.00
# 9    debt_consolidation  small_business              credit_card     1.91
# 10   Debt consolidation        Business  Credit card refinancing     1.91
# 11                   NY              WA                       MI     4.87
# 12                15.17           79.59                    35.07    11.93
# 13                    0               0                        0     0.83
# 14             May-2008        Dec-2010                 Dec-1988     8.40
# 15                    1               2                        0     1.41
# 16                  NaN             NaN                      NaN     6.29
# 17                  NaN              94                      NaN     6.33
# 18                    4               6                       26     4.45
# 19                    0               1                        0     0.48
# 20                 2453           12325                    79282    14.95
# 21                81.8%           59.3%                    46.4%     9.88
# 22                    6               9                       50     5.52
# 23                    f               f                        w     0.31
# 24                    0               0                        0     0.12
# 25                  NaN             NaN                      NaN     6.35
# 26                    1               1                        1     0.00
# 27           Individual       Joint App               Individual     0.55
# 28                  NaN          141000                      NaN     9.14
# 29                  NaN           16.59                      NaN    11.50
# ..                  ...             ...                      ...      ...
# 88                  NaN               9                      NaN     4.65
# 89                  NaN            85.9                      NaN     9.86
# 90                  NaN               5                      NaN     3.17
# 91                  NaN               2                      NaN     4.88
# 92                  NaN               0                      NaN     0.15
# 93                  NaN               0                      NaN     0.30
# 94                  NaN             NaN                      NaN     6.38
# 95                    N               N                        N     0.53
# 96                  NaN       CVD19SKIP                      NaN     0.00
# 97                  NaN      INCOMECURT                      NaN     1.83
# 98                  NaN        COMPLETE                      NaN     0.32
# 99                  NaN               2                      NaN     0.37
# 100                 NaN               0                      NaN     2.43
# 101                 NaN        Apr-2020                      NaN     0.71
# 102                 NaN        May-2020                      NaN     1.43
# 103                 NaN        Mar-2020                      NaN     1.44
# 104                 NaN               2                      NaN     0.37
# 105                 NaN               3                      NaN     0.82
# 106                 NaN   GRACE_CURRENT                      NaN     0.49
# 107                 NaN          393.88                      NaN    13.41
# 108                 NaN         19282.1                      NaN    13.92
# 109                 NaN          668.12                      NaN    11.73
# 110                   N               N                        N     0.00
# 111                 NaN             NaN                      NaN     0.00
# 112                 NaN             NaN                      NaN     0.00
# 113                 NaN             NaN                      NaN     0.00
# 114                 NaN             NaN                      NaN     1.00
# 115                 NaN             NaN                      NaN     0.00
# 116                 NaN             NaN                      NaN     0.00
# 117                 687             667                      697     4.60
#
# [118 rows x 8 columns]

# %% [markdown]
# **Now that we have 118 columns or features. let’s start by handling missing values and first removing the columns that have too many null values that practically we won't be able to use them. As it can be seen in the summary query result from row 100 to 129 the total number of missing values are way more than the total number of data in one column. So, we might be able to remove some of these columns. Let’s dig in.**

# %%
#Let's see how many columns contain null values and how many don't.
print("columns with missing values:", len(df.columns[df.isna().any()]))
print("columns with no missing values:", len(df.columns[df.notna().all()]))
print("All columns in the dataframe:",len(df.columns))
# Out:
# columns with missing values: 118
# columns with no missing values: 0
# All columns in the dataframe: 118

# %% [markdown]
# **Now let’s calculate the Percentage of missing values in each column. I am going to modify my summary function and try to use is to calculate this**

# %%
null_v = df.isnull().sum()
null_v_per = round (100 * df.isnull().sum() / len(df),2)
#now let's create table view of the the two side by side
missing_value_table = pd.DataFrame({'Count': null_v, 'Percent': null_v_per })
missing_value_table[(missing_value_table['Count']>2) & (missing_value_table['Percent']>50)].sort_values('Percent',ascending=False)
# Out:
#                                              Count  Percent
# desc                                        128260   100.00
# debt_settlement_flag_date                   128258   100.00
# settlement_percentage                       128258   100.00
# settlement_amount                           128258   100.00
# settlement_date                             128258   100.00
# settlement_status                           128258   100.00
# settlement_term                             128258   100.00
# sec_app_mths_since_last_major_derog         123235    96.08
# mths_since_last_record                      115316    89.91
# verification_status_joint                   114324    89.13
# deferral_term                               112410    87.64
# hardship_loan_status                        112411    87.64
# hardship_dpd                                112410    87.64
# hardship_length                             112410    87.64
# payment_plan_start_date                     112410    87.64
# hardship_end_date                           112410    87.64
# hardship_start_date                         112410    87.64
# hardship_status                             112410    87.64
# hardship_reason                             112411    87.64
# hardship_type                               112410    87.64
# sec_app_revol_util                          112381    87.62
# sec_app_inq_last_6mths                      112120    87.42
# annual_inc_joint                            112120    87.42
# sec_app_chargeoff_within_12_mths            112120    87.42
# revol_bal_joint                             112120    87.42
# sec_app_num_rev_accts                       112120    87.42
# sec_app_open_act_il                         112120    87.42
# sec_app_open_acc                            112120    87.42
# sec_app_mort_acc                            112120    87.42
# sec_app_collections_12_mths_ex_med          112120    87.42
# sec_app_earliest_cr_line                    112120    87.42
# dti_joint                                   112120    87.42
# hardship_amount                             109142    85.09
# orig_projected_additional_accrued_interest  109142    85.09
# hardship_payoff_balance_amount              109142    85.09
# hardship_last_payment_amount                109142    85.09
# mths_since_recent_bc_dlq                    102551    79.96
# mths_since_last_major_derog                  99974    77.95
# mths_since_recent_revol_delinq               91013    70.96
# mths_since_last_delinq                       72117    56.23

# %% [markdown]
# **As it can be seen there are column or features withn more than 80% missing or null value in them. These feature won't be helping us. So I will drrop any column that has a null value percentage of above %80**

# %%
#too_many_null = [i for i in df.count()<128260 *0.80]
#df.drop(df.columns[too_many_null],axis=1,inplace=True)

df = df.dropna(axis=1, thresh=int(0.80*len(df)))

# %%
print("columns with missing values:", len(df.columns[df.isna().any()]))
print("columns with no missing values:", len(df.columns[df.notna().all()]))
print("All columns in the dataframe:",len(df.columns))
# Out:
# columns with missing values: 78
# columns with no missing values: 0
# All columns in the dataframe: 78

# %%
#let's check the summary again
resumetable(df)
# Out:
# Dataset Shape: (128260, 78)
#                           Name   dtypes  Missing  Uniques         First Value  \
# 0                         term   object        2        2           36 months
# 1                        grade   object        2        4                   C
# 2                   emp_length   object    11233       11             2 years
# 3               home_ownership   object        2        4                RENT
# 4                   annual_inc  float64        2    10082               50000
# 5          verification_status   object        2        3     Source Verified
# 6                  loan_status   object        2        7             Current
# 7                   pymnt_plan   object        2        1                   n
# 8                      purpose   object        2       12  debt_consolidation
# 9                        title   object        2       12  Debt consolidation
# 10                  addr_state   object        2       50                  NY
# 11                         dti  float64      233     6624               15.17
# 12                 delinq_2yrs  float64        2       21                   0
# 13            earliest_cr_line   object        2      647            May-2008
# 14              inq_last_6mths  float64        2        6                   1
# 15                    open_acc  float64        2       70                   4
# 16                     pub_rec  float64        2        6                   0
# 17                   revol_bal  float64        2    42986                2453
# 18                  revol_util   object      191     1074               81.8%
# 19                   total_acc  float64        2      118                   6
# 20         initial_list_status   object        2        2                   f
# 21  collections_12_mths_ex_med  float64        2        6                   0
# 22                 policy_code  float64        2        1                   1
# 23            application_type   object        2        2          Individual
# 24              acc_now_delinq  float64        2        2                   0
# 25                tot_coll_amt  float64        2     3788                   0
# 26                 tot_cur_bal  float64        2   101679               17803
# 27                 open_acc_6m  float64        2       15                   0
# 28                 open_act_il  float64        2       41                   1
# 29                 open_il_12m  float64        2       11                   1
# ..                         ...      ...      ...      ...                 ...
# 48          mo_sin_old_il_acct  float64     3312      465                 139
# 49        mo_sin_old_rev_tl_op  float64        2      679                   9
# 50       mo_sin_rcnt_rev_tl_op  float64        2      241                   9
# 51              mo_sin_rcnt_tl  float64        2      149                   9
# 52                    mort_acc  float64        2       24                   0
# 53        mths_since_recent_bc  float64     1456      379                 NaN
# 54       mths_since_recent_inq  float64    14384       26                   5
# 55       num_accts_ever_120_pd  float64        2       33                   0
# 56              num_actv_bc_tl  float64        2       35                   0
# 57             num_actv_rev_tl  float64        2       42                   1
# 58                 num_bc_sats  float64        2       47                   0
# 59                   num_bc_tl  float64        2       61                   0
# 60                   num_il_tl  float64        2       83                   4
# 61               num_op_rev_tl  float64        2       65                   2
# 62               num_rev_accts  float64        2       94                   2
# 63         num_rev_tl_bal_gt_0  float64        2       42                   1
# 64                    num_sats  float64        2       70                   4
# 65          num_tl_90g_dpd_24m  float64        2       20                   0
# 66          num_tl_op_past_12m  float64        2       21                   3
# 67              pct_tl_nvr_dlq  float64        2      491                 100
# 68            percent_bc_gt_75  float64     1564      184                 NaN
# 69        pub_rec_bankruptcies  float64        2        6                   0
# 70                   tax_liens  float64        2        1                   0
# 71             tot_hi_cred_lim  float64        2    96497               23453
# 72           total_bal_ex_mort  float64        2    79785               17803
# 73              total_bc_limit  float64        2     2216                   0
# 74  total_il_high_credit_limit  float64        2    67879               20453
# 75               hardship_flag   object     3270        2                   N
# 76        debt_settlement_flag   object        2        2                   N
# 77                        FICO  float64        2       38                 687
#
#       Second Value              Third Value  Entropy
# 0        36 months                60 months     0.92
# 1                B                        C     1.96
# 2         < 1 year                10+ years     3.05
# 3             RENT                 MORTGAGE     1.41
# 4            13000                    84000     8.04
# 5         Verified          Source Verified     1.37
# 6          Current                  Current     0.53
# 7                n                        n     0.00
# 8   small_business              credit_card     1.91
# 9         Business  Credit card refinancing     1.91
# 10              WA                       MI     4.87
# 11           79.59                    35.07    11.93
# 12               0                        0     0.83
# 13        Dec-2010                 Dec-1988     8.40
# 14               2                        0     1.41
# 15               6                       26     4.45
# 16               1                        0     0.48
# 17           12325                    79282    14.95
# 18           59.3%                    46.4%     9.88
# 19               9                       50     5.52
# 20               f                        w     0.31
# 21               0                        0     0.12
# 22               1                        1     0.00
# 23       Joint App               Individual     0.55
# 24               0                        0     0.00
# 25               0                        0     2.01
# 26           42566                   242989    16.51
# 27               1                        0     1.96
# 28               1                        1     3.02
# 29               0                        0     1.70
# ..             ...                      ...      ...
# 48             108                      168     7.79
# 49              61                      372     8.47
# 50               4                        7     5.38
# 51               4                        7     4.44
# 52               0                        4     2.26
# 53               7                       21     6.04
# 54               4                        1     4.27
# 55               0                        0     1.18
# 56               2                       11     3.18
# 57               5                       18     3.61
# 58               2                       14     3.54
# 59               2                       20     4.00
# 60               4                        8     4.56
# 61               5                       24     4.12
# 62               5                       38     4.76
# 63               5                       18     3.61
# 64               6                       26     4.45
# 65               0                        0     0.29
# 66               2                        2     2.71
# 67             100                      100     4.00
# 68              50                     21.4     3.73
# 69               1                        0     0.48
# 70               0                        0     0.00
# 71           60800                   351386    16.12
# 72           42566                    80128    16.08
# 73            5200                   123800     9.52
# 74           40000                    16158    14.19
# 75               N                        N     0.53
# 76               N                        N     0.00
# 77             667                      697     4.60
#
# [78 rows x 8 columns]

# %% [markdown]
# **From above we can see that there are a few columns that have only one unique value. Those also won't be helpful in our modeling. We will dropm them as well.**

# %%
df = df.loc[:,df.apply(pd.Series.nunique) != 1]

# %% [markdown]
# There are also a few columns with more than 1 unique value but one of the unique values has been repeated many times. so, the other ones don’t matter much. That makes these columns similar to the ones with only one unique value. So, we can drop them too. I checked those for columns that had less than 6 unique value and end up with going with the ones with only 4.

# %%
for i in df.columns:
    if (len(df[i].unique())<4):
        print(df[i].value_counts())
        print()
# Out:
#  36 months    85338
#  60 months    42920
# Name: term, dtype: int64
#
# w    121116
# f      7142
# Name: initial_list_status, dtype: int64
#
# Individual    112118
# Joint App      16140
# Name: application_type, dtype: int64
#
# 0.0    128236
# 1.0        22
# Name: acc_now_delinq, dtype: int64
#
# N    110075
# Y     14915
# Name: hardship_flag, dtype: int64
#
# N    128256
# Y         2
# Name: debt_settlement_flag, dtype: int64

# %%
df=df.drop (['debt_settlement_flag','acc_now_delinq',
'initial_list_status'],axis=1)

# %%
df.shape
# Out:
# (128260, 72)

# %% [markdown]
# **Lets see how many more columns that have more than 2 missding values are left and what is their data type.

# %%
null_v2 = df.isnull().sum()
null_v2_Data_type=null_v2.dtypes
null_v_per2 = round (100 * df.isnull().sum() / len(df),2)
#now let's create table view of the the two side by side
missing_value_table2 = pd.DataFrame({'Count': null_v2, 'Percent': null_v_per2, 'Data_type':null_v2_Data_type })
final_missning=missing_value_table2[missing_value_table2['Count'] >2].sort_values('Percent',ascending=False)
final_missning
# Out:
#                        Count  Percent Data_type
# il_util                17065    13.31     int64
# mths_since_recent_inq  14384    11.21     int64
# emp_length             11233     8.76     int64
# mths_since_rcnt_il      3312     2.58     int64
# mo_sin_old_il_acct      3312     2.58     int64
# hardship_flag           3270     2.55     int64
# bc_util                 1632     1.27     int64
# bc_open_to_buy          1562     1.22     int64
# percent_bc_gt_75        1564     1.22     int64
# mths_since_recent_bc    1456     1.14     int64
# dti                      233     0.18     int64
# revol_util               191     0.15     int64
# all_util                  26     0.02     int64
# avg_cur_bal                9     0.01     int64

# %% [markdown]
# **All 14 above columns with more than 2 missing values have a data type of integer. We can easily find a solution to handel the missing values in this columns. But first let's look through the description and see if there is anything that won't be useful so we can drop.

# %%
final_missning2 = final_missning.reset_index()
final_missning2['Name'] = final_missning2['index']
final_missning2 = final_missning2[['Name','Data_type']]
vlookup2 = final_missning2.merge(dic_des, on='Name',how='left')
vlookup2.style.set_properties(subset=['Description'], **{'width': '1000px'})
# Out:
# <style  type="text/css" >
#     #T_2eaef392_ab73_11ea_b1cd_0026bb688216row0_col2 {
#             width:  1000px;
#         }    #T_2eaef392_ab73_11ea_b1cd_0026bb688216row1_col2 {
#             width:  1000px;
#         }    #T_2eaef392_ab73_11ea_b1cd_0026bb688216row2_col2 {
#             width:  1000px;
#         }    #T_2eaef392_ab73_11ea_b1cd_0026bb688216row3_col2 {
#             width:  1000px;
#         }    #T_2eaef392_ab73_11ea_b1cd_0026bb688216row4_col2 {
#             width:  1000px;
#         }    #T_2eaef392_ab73_11ea_b1cd_0026bb688216row5_col2 {
#             width:  1000px;
#         }    #T_2eaef392_ab73_11ea_b1cd_0026bb688216row6_col2 {
#             width:  1000px;
#         }    #T_2eaef392_ab73_11ea_b1cd_0026bb688216row7_col2 {
#             width:  1000px;
#         }    #T_2eaef392_ab73_11ea_b1cd_0026bb688216row8_col2 {
#             width:  1000px;
#         }    #T_2eaef392_ab73_11ea_b1cd_0026bb688216row9_col2 {
#             width:  1000px;
#         }    #T_2eaef392_ab73_11ea_b1cd_0026bb688216row10_col2 {
#             width:  1000px;
#         }    #T_2eaef392_ab73_11ea_b1cd_0026bb688216row11_col2 {
#             width:  1000px;
#         }    #T_2eaef392_ab73_11ea_b1cd_0026bb688216row12_col2 {
#             width:  1000px;
#         }    #T_2eaef392_ab73_11ea_b1cd_0026bb688216row13_col2 {
#             width:  1000px;
#         }</style>
# <table id="T_2eaef392_ab73_11ea_b1cd_0026bb688216" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Name</th>
#         <th class="col_heading level0 col1" >Data_type</th>
#         <th class="col_heading level0 col2" >Description</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_2eaef392_ab73_11ea_b1cd_0026bb688216level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_2eaef392_ab73_11ea_b1cd_0026bb688216row0_col0" class="data row0 col0" >il_util</td>
#         <td id="T_2eaef392_ab73_11ea_b1cd_0026bb688216row0_col1" class="data row0 col1" >int64</td>
#         <td id="T_2eaef392_ab73_11ea_b1cd_0026bb688216row0_col2" class="data row0 col2" >Ratio of total current balance to high credit/credit limit on all install acct</td>
#     </tr>    <tr>
#         <th id="T_2eaef392_ab73_11ea_b1cd_0026bb688216level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_2eaef392_ab73_11ea_b1cd_0026bb688216row1_col0" class="data row1 col0" >mths_since_recent_inq</td>
#         <td id="T_2eaef392_ab73_11ea_b1cd_0026bb688216row1_col1" class="data row1 col1" >int64</td>
#         <td id="T_2eaef392_ab73_11ea_b1cd_0026bb688216row1_col2" class="data row1 col2" >Months since most recent inquiry.</td>
#     </tr>    <tr>
#         <th id="T_2eaef392_ab73_11ea_b1cd_0026bb688216level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_2eaef392_ab73_11ea_b1cd_0026bb688216row2_col0" class="data row2 col0" >emp_length</td>
#         <td id="T_2eaef392_ab73_11ea_b1cd_0026bb688216row2_col1" class="data row2 col1" >int64</td>
#         <td id="T_2eaef392_ab73_11ea_b1cd_0026bb688216row2_col2" class="data row2 col2" >Employment length in years. Possible values are between 0 and 10 where 0 means less than one year and 10 means ten or more years.</td>
#     </tr>    <tr>
#         <th id="T_2eaef392_ab73_11ea_b1cd_0026bb688216level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_2eaef392_ab73_11ea_b1cd_0026bb688216row3_col0" class="data row3 col0" >mths_since_rcnt_il</td>
#         <td id="T_2eaef392_ab73_11ea_b1cd_0026bb688216row3_col1" class="data row3 col1" >int64</td>
#         <td id="T_2eaef392_ab73_11ea_b1cd_0026bb688216row3_col2" class="data row3 col2" >Months since most recent installment accounts opened</td>
#     </tr>    <tr>
#         <th id="T_2eaef392_ab73_11ea_b1cd_0026bb688216level0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_2eaef392_ab73_11ea_b1cd_0026bb688216row4_col0" class="data row4 col0" >mo_sin_old_il_acct</td>
#         <td id="T_2eaef392_ab73_11ea_b1cd_0026bb688216row4_col1" class="data row4 col1" >int64</td>
#         <td id="T_2eaef392_ab73_11ea_b1cd_0026bb688216row4_col2" class="data row4 col2" >Months since oldest bank installment account opened</td>
#     </tr>    <tr>
#         <th id="T_2eaef392_ab73_11ea_b1cd_0026bb688216level0_row5" class="row_heading level0 row5" >5</th>
#         <td id="T_2eaef392_ab73_11ea_b1cd_0026bb688216row5_col0" class="data row5 col0" >hardship_flag</td>
#         <td id="T_2eaef392_ab73_11ea_b1cd_0026bb688216row5_col1" class="data row5 col1" >int64</td>
#         <td id="T_2eaef392_ab73_11ea_b1cd_0026bb688216row5_col2" class="data row5 col2" >Flags whether or not the borrower is on a hardship plan</td>
#     </tr>    <tr>
#         <th id="T_2eaef392_ab73_11ea_b1cd_0026bb688216level0_row6" class="row_heading level0 row6" >6</th>
#         <td id="T_2eaef392_ab73_11ea_b1cd_0026bb688216row6_col0" class="data row6 col0" >bc_util</td>
#         <td id="T_2eaef392_ab73_11ea_b1cd_0026bb688216row6_col1" class="data row6 col1" >int64</td>
#         <td id="T_2eaef392_ab73_11ea_b1cd_0026bb688216row6_col2" class="data row6 col2" >Ratio of total current balance to high credit/credit limit for all bankcard accounts.</td>
#     </tr>    <tr>
#         <th id="T_2eaef392_ab73_11ea_b1cd_0026bb688216level0_row7" class="row_heading level0 row7" >7</th>
#         <td id="T_2eaef392_ab73_11ea_b1cd_0026bb688216row7_col0" class="data row7 col0" >bc_open_to_buy</td>
#         <td id="T_2eaef392_ab73_11ea_b1cd_0026bb688216row7_col1" class="data row7 col1" >int64</td>
#         <td id="T_2eaef392_ab73_11ea_b1cd_0026bb688216row7_col2" class="data row7 col2" >Total open to buy on revolving bankcards.</td>
#     </tr>    <tr>
#         <th id="T_2eaef392_ab73_11ea_b1cd_0026bb688216level0_row8" class="row_heading level0 row8" >8</th>
#         <td id="T_2eaef392_ab73_11ea_b1cd_0026bb688216row8_col0" class="data row8 col0" >percent_bc_gt_75</td>
#         <td id="T_2eaef392_ab73_11ea_b1cd_0026bb688216row8_col1" class="data row8 col1" >int64</td>
#         <td id="T_2eaef392_ab73_11ea_b1cd_0026bb688216row8_col2" class="data row8 col2" >Percentage of all bankcard accounts > 75% of limit.</td>
#     </tr>    <tr>
#         <th id="T_2eaef392_ab73_11ea_b1cd_0026bb688216level0_row9" class="row_heading level0 row9" >9</th>
#         <td id="T_2eaef392_ab73_11ea_b1cd_0026bb688216row9_col0" class="data row9 col0" >mths_since_recent_bc</td>
#         <td id="T_2eaef392_ab73_11ea_b1cd_0026bb688216row9_col1" class="data row9 col1" >int64</td>
#         <td id="T_2eaef392_ab73_11ea_b1cd_0026bb688216row9_col2" class="data row9 col2" >Months since most recent bankcard account opened.</td>
#     </tr>    <tr>
#         <th id="T_2eaef392_ab73_11ea_b1cd_0026bb688216level0_row10" class="row_heading level0 row10" >10</th>
#         <td id="T_2eaef392_ab73_11ea_b1cd_0026bb688216row10_col0" class="data row10 col0" >dti</td>
#         <td id="T_2eaef392_ab73_11ea_b1cd_0026bb688216row10_col1" class="data row10 col1" >int64</td>
#         <td id="T_2eaef392_ab73_11ea_b1cd_0026bb688216row10_col2" class="data row10 col2" >A ratio calculated using the borrower’s total monthly debt payments on the total debt obligations, excluding mortgage and the requested LC loan, divided by the borrower’s self-reported monthly income.</td>
#     </tr>    <tr>
#         <th id="T_2eaef392_ab73_11ea_b1cd_0026bb688216level0_row11" class="row_heading level0 row11" >11</th>
#         <td id="T_2eaef392_ab73_11ea_b1cd_0026bb688216row11_col0" class="data row11 col0" >revol_util</td>
#         <td id="T_2eaef392_ab73_11ea_b1cd_0026bb688216row11_col1" class="data row11 col1" >int64</td>
#         <td id="T_2eaef392_ab73_11ea_b1cd_0026bb688216row11_col2" class="data row11 col2" >Revolving line utilization rate, or the amount of credit the borrower is using relative to all available revolving credit.</td>
#     </tr>    <tr>
#         <th id="T_2eaef392_ab73_11ea_b1cd_0026bb688216level0_row12" class="row_heading level0 row12" >12</th>
#         <td id="T_2eaef392_ab73_11ea_b1cd_0026bb688216row12_col0" class

# %% [markdown]
# ***AlL the above seems to be usful, therefore we proceed to imputation. Imputation simply means replacing the missing values with an estimate. There are many different approaches and technics to imputation. There are only 3 columns that have a missing value percentage of grater than 3 % of total data. I will imputate those first.

# %%
#"il_util" = Ratio of total current balance to high credit/credit limit on all install acct. 
#For this ratio column I will replace missing values the mean value of the column
df['il_util'].fillna(df['il_util'].mean(),inplace=True)

# %%
#mths_since_recent_inq= Months since most recent inquiry. For this column I will use fill with max value since if 
# there is no value this means that there has never been a recent inquiry so the month since that time would be max. 
#For this ratio column I will replace missing values the mean value of the column
df['mths_since_recent_inq'].fillna(df['mths_since_recent_inq'].max(),inplace=True)

# %%
#emp_length= Employment length in years. Possible values are between 0 and 10 where 0 means less than one year and 10
#means ten or more years. First we need to fix the records with < 1 year and 10+ years and re[lace them with 0 years
#and 11 years according to the description. Then we will need to fix the data type to float. 
df['emp_length'] = df['emp_length'].replace({'< 1 year': '0 years', '10+ years': '11 years'})

# %%
#now We will replace the missimng values with 0 assuming that the borrower didn't have any employmnet history or had it for less than a year.
#Also, I'll be using regex to extract the number of years from all of the data.
df['emp_length'].fillna(value=0,inplace=True)
df['emp_length'].replace(to_replace='[^0-11]+', value='', inplace=True, regex=True)

# %%
#Let's just check if it makes sense. It appear that it makes sense. The browser with 10 or higher years of employment 
#got a loan approval more than the others.
df['emp_length'].value_counts().sort_values().plot(kind='barh',figsize=(18,8))
plt.title('Number of loans distributed by Employment Years',fontsize=20)
plt.xlabel('Number of loans',fontsize=15)
plt.ylabel('Years worked',fontsize=15);

# %% [markdown]
# For all other columns that have missing vaue perncentage of 3 or less than 3% of total values,Since we have enough data to work on I am not going to use any of the imputation technics here. For simlicity I will just drop/delete the rows wehre there is a missing value.

# %%
## dropping the null rows since we have sufficient amount of data and there is no need to fill the null values.
df.dropna(axis=0,inplace=True)

# %%
df.isnull().sum()
# Out:
# term                          0
# grade                         0
# emp_length                    0
# home_ownership                0
# annual_inc                    0
# verification_status           0
# loan_status                   0
# purpose                       0
# title                         0
# addr_state                    0
# dti                           0
# delinq_2yrs                   0
# earliest_cr_line              0
# inq_last_6mths                0
# open_acc                      0
# pub_rec                       0
# revol_bal                     0
# revol_util                    0
# total_acc                     0
# collections_12_mths_ex_med    0
# application_type              0
# tot_coll_amt                  0
# tot_cur_bal                   0
# open_acc_6m                   0
# open_act_il                   0
# open_il_12m                   0
# open_il_24m                   0
# mths_since_rcnt_il            0
# total_bal_il                  0
# il_util                       0
#                              ..
# chargeoff_within_12_mths      0
# delinq_amnt                   0
# mo_sin_old_il_acct            0
# mo_sin_old_rev_tl_op          0
# mo_sin_rcnt_rev_tl_op         0
# mo_sin_rcnt_tl                0
# mort_acc                      0
# mths_since_recent_bc          0
# mths_since_recent_inq         0
# num_accts_ever_120_pd         0
# num_actv_bc_tl                0
# num_actv_rev_tl               0
# num_bc_sats                   0
# num_bc_tl                     0
# num_il_tl                     0
# num_op_rev_tl                 0
# num_rev_accts                 0
# num_rev_tl_bal_gt_0           0
# num_sats                      0
# num_tl_90g_dpd_24m            0
# num_tl_op_past_12m            0
# pct_tl_nvr_dlq                0
# percent_bc_gt_75              0
# pub_rec_bankruptcies          0
# tot_hi_cred_lim               0
# total_bal_ex_mort             0
# total_bc_limit                0
# total_il_high_credit_limit    0
# hardship_flag                 0
# FICO                          0
# Length: 72, dtype: int64

# %%
df.shape
# Out:
# (120079, 72)

# %% [markdown]
# ***Still working on this project. come back for update
